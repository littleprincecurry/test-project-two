# %%
import pymongo
import pandas as pd

# %%
df = pd.read_json('final_data_cleaned.json')
df.head()
# Out:
#      Keyword    Source                             Author  \
# 0  immigrant  Politico                      Josh Gerstein
# 1  immigrant  Politico                     Mackenzie Mays
# 2  immigrant  Politico                     By Erin Durkin
# 3  immigrant  Politico                      Janaki Chadha
# 4  immigrant  Politico  Sabrina Rodriguez and Marc Caputo
#
#                                                Title  \
# 0  Appeals court OKs Trump plan to end protected ...
# 1  California schools launch anti-racism plan, fl...
# 2  De Blasio calls Trump's funding threat 'insult...
# 3  How the left killed another major NYC development
# 4  ‘This is f—ing crazy’: Florida Latinos swamped...
#
#                                                  URL  \
# 0  https://www.politico.com/news/2020/09/14/court...
# 1  https://www.politico.com/states/california/sto...
# 2  https://www.politico.com/news/2020/09/24/de-bl...
# 3  https://www.politico.com/news/2020/09/25/how-t...
# ...

# %%
client_url = 'mongodb+srv://littleprincecurry:Arz9rWJm8xy8808F@clusterprime.mpaq0.mongodb.net/test?authSource=admin&replicaSet=atlas-ppsaa5-shard-0&readPreference=primary&appname=MongoDB%20Compass&ssl=true'

myclient = pymongo.MongoClient(client_url)

# %%
mydb = myclient['ETL']
mycol = mydb['NFTA']

# %%
mydb.NFTA
# Out:
# Collection(Database(MongoClient(host=['clusterprime-shard-00-02.mpaq0.mongodb.net:27017', 'clusterprime-shard-00-01.mpaq0.mongodb.net:27017', 'clusterprime-shard-00-00.mpaq0.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-ppsaa5-shard-0', readpreference='primary', appname='MongoDB Compass', ssl=True), 'ETL'), 'NFTA')

# %%
print(mycol.find_one({'Source': 'Politico'}))
# Out:
# {'_id': ObjectId('5fc583b4c858272aa494f8ae'), 'Keyword': 'immigrant', 'Source': 'Politico', 'Author': 'Josh Gerstein', 'Title': 'Appeals court OKs Trump plan to end protected immigration status for 4 countries', 'URL': 'https://www.politico.com/news/2020/09/14/court-trump-protected-immigration-414520', 'Text': 'The Secretarys discretion to make TPS determinations, while not without check, is undoubtedly broad and unique in nature, Judge Consuelo Callahan wrote in the appeals courts majority opinion, joined … [+4671 chars]', 'Published': '2020-09-14T19:24:12Z', 'compound score': 0.4404, 'negative score': 0, 'positive score': 0.209, 'neutral score': 0.791, 'Full Text Clean': '“The Secretary’s discretion to make TPS determinations, while not without check, is undoubtedly broad and unique in nature,” Judge Consuelo Callahan wrote in the appeals court’s majority opinion, joined by Judge Ryan Nelson. “The decision to designate any foreign country for TPS begins and ends with the Secretary,
# ...

# %%
for x in mycol.find({"Source": "Politico"}):
    print(x)
# Out:
# {'_id': ObjectId('5fc583b4c858272aa494f8ae'), 'Keyword': 'immigrant', 'Source': 'Politico', 'Author': 'Josh Gerstein', 'Title': 'Appeals court OKs Trump plan to end protected immigration status for 4 countries', 'URL': 'https://www.politico.com/news/2020/09/14/court-trump-protected-immigration-414520', 'Text': 'The Secretarys discretion to make TPS determinations, while not without check, is undoubtedly broad and unique in nature, Judge Consuelo Callahan wrote in the appeals courts majority opinion, joined … [+4671 chars]', 'Published': '2020-09-14T19:24:12Z', 'compound score': 0.4404, 'negative score': 0, 'positive score': 0.209, 'neutral score': 0.791, 'Full Text Clean': '“The Secretary’s discretion to make TPS determinations, while not without check, is undoubtedly broad and unique in nature,” Judge Consuelo Callahan wrote in the appeals court’s majority opinion, joined by Judge Ryan Nelson. “The decision to designate any foreign country for TPS begins and ends with the Secretary,
# ...

# %%
pd.DataFrame.from_dict(mycol)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-72d04ee8f7bb> in <module>
# ----> 1 pd.DataFrame.from_dict(mycol)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in from_dict(cls, data, orient, dtype, columns)
#    1307             raise ValueError("only recognize index or columns for orient")
#    1308
# -> 1309         return cls(data, index=index, columns=columns, dtype=dtype)
#    1310
#    1311     def to_numpy(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     500         elif isinstance(data, abc.Iterable) and not isinstance(data, (str, bytes)):
#     501             if not isinstance(data, (abc.Sequence, ExtensionArray)):
# --> 502                 data = list(data)
#     503             if len(data) > 0:
# ...

# %%
df2 = pd.DataFrame(list(mycol.find()))
# Out:
#                            _id    Keyword    Source  \
# 0     5fc583b4c858272aa494f8ae  immigrant  Politico
# 1     5fc583b4c858272aa494f8af  immigrant  Politico
# 2     5fc583b4c858272aa494f8b0  immigrant  Politico
# 3     5fc583b4c858272aa494f8b1  immigrant  Politico
# 4     5fc583b4c858272aa494f8b2  immigrant  Politico
# ...                        ...        ...       ...
# 2658  5fc583c2c858272aa4950310    migrant       CNN
# 2659  5fc583c2c858272aa4950311    migrant       CNN
# 2660  5fc583c2c858272aa4950312    migrant       CNN
# 2661  5fc583c2c858272aa4950313   migrants       CNN
# 2662  5fc583c2c858272aa4950314   migrants       CNN
#
#                                                  Author  \
# 0                                         Josh Gerstein
# 1                                        Mackenzie Mays
# 2                                        By Erin Durkin
# 3                                         Janaki Chadha
# ...
